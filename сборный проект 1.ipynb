# %% [markdown]
# <font color='DarkBlue' size=+2><b>Комментарий ревьюера</b></font><br>
# <font color='DarkBlue'>Привет, Станислав! <br>Меня зовут Олег Мазуренко, и я буду проверять этот проект. Спасибо за проделанную работу! <br>Ко мне можно обращаться на «ты». Как мне обращаться, напиши.</font><br>
# <font color='DarkBlue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font><br>
# <font color='DarkBlue'>Синий текст &mdash; просто текст комментария.</font><br>
# <font color='DarkGreen'>👌 Зеленый текст &mdash; все отлично.</font><br>
# <font color='DarkMagenta'>👉 Фиолетовый текст &mdash; сделано все правильно, однако есть рекомендации, на что стоит обратить внимание. Реализованные рекомендации позволят нам наработать опыт решения задачи разными способами или посмотреть на задачу под иным углом.</font><br>
# <font color='Red'>🛠 Красный текст &mdash; есть недочеты, они иногда бывают. </font><br><font color='DarkBlue'>Любая ошибка это возможность посмотреть на задачу с другой стороны и освоить новые знания, по этому не надо расстраиваться, если они есть.</font><br>
# <font color='DarkBlue'>Пожалуйста, не удаляй мои комментарии в случае возврата работы, так будет проще разобраться, какие были недочеты и сразу увидеть исправленное. <br>
# Ответы на мои комментарии лучше тоже помечать.
# Например: </font><font color='Blue'><b>Комментарий студента</b></font><br>
# <font color='DarkBlue'><b>Теперь посмотрим, что у нас получилось!</b></font>

# %% [markdown]
# # Сборный проект

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделали описание проекта. 👍</font>

# %% [markdown]
# ## .     Изучение, подготовка и изменения  данных.

# %%
import pandas as pd # импортирем библиотеку pandas
import matplotlib.pyplot as plt #импортируем для работы с графиками
data=pd.read_csv("/datasets/games.csv")# прочитаем csv-файл

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Лучше разделять по разным ячейкам загрузку библиотек и датасета.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌  Входе работы иногда приходится дополнительно загружать другие библиотеки, их вставляем в первую ячейку и перезагружаем. Так как датасет грузится отдельно, то можем продолжить работу с таблицей, которую уже обработали и преобразовали. А если у нас все в одном флаконе, то придется перезагружать всю тетрадку. При очень больших датасетах это может быть длительной процедурой. </font>

# %%
data # посмотрим в каком виде представлены данные
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 0         41.36     28.96      3.77         8.45          76.0          8
# 1         29.08      3.58      6.81         0.77           NaN        NaN
# 2         15.68     12.76      3.79         3.29          82.0        8.3
# 3         15.61     10.93      3.28         2.95          80.0          8
# 4         11.27      8.89     10.22         1.00           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 16710      0.00      0.00      0.01         0.00           NaN        NaN
# 16711      0.00      0.01      0.00         0.00           NaN        NaN
# 16712      0.00      0.00      0.01         0.00           NaN        NaN
# 16713      0.01      0.00      0.00         0.00           NaN        NaN
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
#
#       Rating
# 0          E
# 1        NaN
# 2          E
# 3          E
# 4        NaN
# ...      ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
#
# [16715 rows x 11 columns]

# %%
data.info()#получаем подробную информацию по датасету
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data.columns = data.columns.str.lower()#приведем названия столбцов к нижнему регистру

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Молодец! 👍 Не которые пишут длинный словарь для замены колонок.</font>

# %%
data.hist(figsize=(15, 20))#создам общую гистограмму для всех числовых столбцов таблицы.
# Out:
# array([[<AxesSubplot:title={'center':'year_of_release'}>,
#         <AxesSubplot:title={'center':'na_sales'}>],
#        [<AxesSubplot:title={'center':'eu_sales'}>,
#         <AxesSubplot:title={'center':'jp_sales'}>],
#        [<AxesSubplot:title={'center':'other_sales'}>,
#         <AxesSubplot:title={'center':'critic_score'}>]], dtype=object)

# %%
data.duplicated().sum()#проверим наличие явных дупликатов
# Out:
# 0

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что проверены дубликаты, иногда они сильно искажают анализ.</font>

# %%
data.isna().sum()#смотрим общее кол-во пропусков и опрелделяем в каких колонках они находятся
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Данные с пропусками в имени и жанре удалим, т.к. их всего 2 штуки а эти данные нам будут нужны в полном объеме. Так же поменяем значения в столбцах (оценки пользователей и рейтинг) на INT.Удалим строки с отсутсвуеющими данными года релиза

# %%
data=data.dropna(subset=['name'])
data=data.reset_index(drop=True)# удаляем строки где не указано название игры

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что удалили пропуски в названии игр, тем более в этих строках еще хватает пропусков по другим колонкам.</font>

# %%
data=data.dropna(subset=['genre'])
data=data.reset_index(drop=True)# удаляем строки где не указан жанр игры

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 А пропусков в жанрах уже нет.</font>

# %%
data=data.dropna(subset=['year_of_release'])
data=data.reset_index(drop=True)# удаляем строки где отсутсвует год релиза

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильное решение по удалению пропусков в годе релиза. Хорошо, что было проверено количество пропусков.</font>

# %%
data.isna().sum()#смотрим общее кол-во пропусков и опрелделяем в каких колонках они находятся
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         6605
# rating             6676
# dtype: int64

# %%
data.shape
# Out:
# (16444, 11)

# %% [markdown]
# Данных после удаления осталось 98.3% , что в пределах нормы.

# %% [markdown]
# Посмотрим сколько значений в стобцах рейтинг, оценка критиков и оценка пользхователей равный 0.

# %%
len(data[(data['user_score']=="0")])
# Out:
# 1

# %%
len(data[(data['critic_score']=="0")])
# Out:
# 0

# %% [markdown]
# Пропуски в оценках сделаем 0 что будет означать что его нет. Так же поступим с пользовательской оценкой и оценкой критиков. Т.к. данных с 0 оценко  нет, что логично т.к. игры с полностью отсутсвующим рейтингом очень мало. Он может быть низким и стремиться к 0, но принять значение 0 может в очень редкис случаях. что мы и видит из данных.

# %% [markdown]
# Что касаеться рейтинга ESRB онлайн проектам не присваивается никакой  рейтинг. Онлайн-контент, общение в голосовом чате и пользовательский контент, не оцениваются ESRB, поскольку они не считаются частью процесса оценки.
# Так же этот рейтинг актуален по большей части к Америке. Т.К. это не государсвенная организация и рейтинг в разных странах может отличаться либо не присваиваться вовсе.Заменим эти значения на 0.

# %%
data["critic_score"]=data["critic_score"].fillna(-1)# меняем пропуск на 0 что будет означать отсутсвие

# %%
data["user_score"]=data["user_score"].fillna(-1)# меняем пропуск на 0 что будет означать отсутсвие

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Если это заглушка в отзывах, то лучше было поставить отрицательное число, а потом при анализе его фильтровать.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера: Глоссарий</b></font><br>
# <font color='DarkGreen'>👌 В контексте анализа и предобработки датасета часто используютется термин: <b>Заглушка</b>. <br>Из словаря: "Заглушка — приспособление для закрывания отверстия наглухо." <br>В нашем контексте закрытие пропуска в датасете каким-то значением, совпадающим по типу с данными колонки таблицы. Как правило, для числовых данных заглушка должна быть вне диапазона значений колонки. При анализе по данной колонке заглушка или фильтруется, или включается в анализ, если сам пропуск не является ошибкой сбора данных и несет какой-то признак. <br>Частая ошибка, когда заглушке присваивается числовое значение, например `0`, а в данных колонки присутствуют значения `'0'`, то при преобразовании к числовому типу произойдет слияние значимых данных таблицы и заглушки.</font>

# %%
data["rating"]=data["rating"].fillna(-1)# меняем пропуск на 0 что будет означать отсутсвие

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Правильно поставлена заглушка на пропуски в колонке рейтинга. А если посмотреть в интернете, что такое рейтинг ESRB, то мы узнаем, что это рейтинг для США и Канады. А значит пропуск не савязан с ошибкой заполнения данных, просто не только для Северной Америки выпускаются игры.</font><br>
# <font color='DarkMagenta'>👉 Только не очень хорошо вставлять числовую заглушку в колонку рейтинга, когда данные в колонке строковые. Не корректно смешивать разные типы данных в одной колонке.</font>

# %% [markdown]
# Посмотрим какие есть уникальные значения в этих столбцах.

# %%
data["critic_score"].unique()
# Out:
# array([76., -1., 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 41., 36., 31., 27., 35., 26., 19., 28., 23.,
#        24., 21., 17., 13.])

# %%
data["user_score"].unique()
# Out:
# array(['8', -1, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
data["rating"].unique()
# Out:
# array(['E', -1, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Значение tbd( означает что игра в процессе оценки) заменим на 0 т.к. их тоже нет.

# %%
import numpy as np

# %%
#for d in data["user_score"].unique():
    #data.loc[(data["user_score"]=='tbd')]=0
data.loc[data['user_score'] == 'tbd','user_score'] = np.nan 
data['user_score'] = data['user_score'].fillna(-1)

# %% [markdown]
# </font><font color='Blue'><b>Здесь случайно удалиил ваш коментарий что я заменил tbd на 0 неправильно и это ошибка ,случайно.Поменял на значение -1</b></font><br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Комментарий ревьюера
data.loc[data["year_of_release"]==0]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# Поменяем значения в столбцах оценки пользователей на float. Так же поменяем на инт год выхода т.к кроме года не указывается месяц и день выхода, соответсвенно не имеет смысла менять их с помощью to_datetime.

# %%
len(data[data['user_score'] =="tbd"])
# Out:
# 0

# %%
data["user_score"]=data["user_score"].astype("float64")

# %%
data["year_of_release"]=data["year_of_release"].astype("int")

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что перевели типы данных. 👍</font>

# %%
data.info()#проверим
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     16444 non-null  float64
#  9   user_score       16444 non-null  float64
#  10  rating           16444 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Посчитаем сумарные продажи во всех регионах.

# %%
data["sum_sales"]=data["na_sales"]+data["eu_sales"]+data["jp_sales"]+data["other_sales"]

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Мы молодцы, не забыли создать колонку с общими продажами. 👍 <br> А можно использовать вот такой код:</font><br>
# ` = data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)`

# %%
data.describe()# посмотрим статистику всех числовых столбцов
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     16444.000000  16444.000000  16444.000000  16444.000000
# mean       2006.486256      0.264012      0.145930      0.078487
# std           5.875525      0.818378      0.506716      0.311100
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         other_sales  critic_score    user_score     sum_sales
# count  16444.000000  16444.000000  16444.000000  16444.000000
# mean       0.047594     32.979871      2.688081      0.536023
# std        0.188005     36.302947      4.170124      1.558786
# min        0.000000     -1.000000     -1.000000      0.000000
# 25%        0.000000     -1.000000     -1.000000      0.060000
# 50%        0.010000     -1.000000     -1.000000      0.170000
# 75%        0.030000     70.000000      7.300000      0.470000
# max       10.570000     98.000000      9.700000     82.540000

# %% [markdown]
# Посчитаем Строки с выходом игры в 0 году.

# %%
len(data[data['year_of_release'] == 0])
# Out:
# 0

# %% [markdown]
# Значений слишком много, удалять их нельзя. При дальнейшем анализе там где год выпуска будет важен, не будем учитывать эти данные.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 А зачем мы строили гистограммы в начале предобработки? Там нулей не было, тут они появились. Может стоило разобраться в этом и найти ошибку?</font>

# %% [markdown]
# Аномалий не выявлено.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Выявлено.</font>

# %% [markdown]
# </font><font color='Blue'><b>Все исправил</b></font><br>

# %%
# Комментарий ревьюера
# Посмотрим, что у нас осталось
temp = data.copy() 
list_c = ['name', 'platform', 'year_of_release', 'genre', 'critic_score', 'user_score', 'rating']
print(temp.info())
for col_l in list_c:
  print('-'* 25)
  print(col_l, temp[col_l].unique())
  print(col_l,' : кол-во 0', temp[temp[col_l] == 0][col_l].count(),
        ', процент 0', round(temp[temp[col_l] == 0][col_l].count()/len(temp)*100, 2),'%')
  print(col_l,': кол-во NaN',temp[col_l].isna().sum(),
        ', процент NaN', round(temp[col_l].isna().sum()/len(temp)*100, 2),'%')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     16444 non-null  float64
#  9   user_score       16444 non-null  float64
#  10  rating           16444 non-null  object
#  11  sum_sales        16444 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.5+ MB
# None
# -------------------------
# name ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ...
#  'Woody Woodpecker in Crazy Castle 5' 'LMA Manager 2007'
#  'Haitaka no Psychedelica']
# name  : кол-во 0 0 , процент 0 0.0 %
# name : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# platform ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
# platform  : кол-во 0 0 , процент 0 0.0 %
# platform : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# year_of_release [2006 1985 2008 2009 1996 1989 1984 2005 1999 2007 2010 2013 2004 1990
#  1988 2002 2001 2011 1998 2015 2012 2014 1992 1997 1993 1994 1982 2016
#  2003 1986 2000 1995 1991 1981 1987 1980 1983]
# year_of_release  : кол-во 0 0 , процент 0 0.0 %
# year_of_release : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# genre ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']
# genre  : кол-во 0 0 , процент 0 0.0 %
# genre : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# critic_score [76. -1. 82. 80. 89. 58. 87. 91. 61. 97. 95. 77. 88. 83. 94. 93. 85. 86.
#  98. 96. 90. 84. 73. 74. 78. 92. 71. 72. 68. 62. 49. 67. 81. 66. 56. 79.
#  70. 59. 64. 75. 60. 63. 69. 50. 25. 42. 44. 55. 48. 57. 29. 47. 65. 54.
#  20. 53. 37. 38. 33. 52. 30. 32. 43. 45. 51. 40. 46. 39. 34. 41. 36. 31.
#  27. 35. 26. 19. 28. 23. 24. 21. 17. 13.]
# critic_score  : кол-во 0 0 , процент 0 0.0 %
# critic_score : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# user_score [ 8.  -1.   8.3  8.5  6.6  8.4  8.6  7.7  6.3  7.4  8.2  9.   7.9  8.1
#   8.7  7.1  3.4  5.3  4.8  3.2  8.9  6.4  7.8  7.5  2.6  7.2  9.2  7.
#   7.3  4.3  7.6  5.7  5.   9.1  6.5  8.8  6.9  9.4  6.8  6.1  6.7  5.4
#   4.   4.9  4.5  9.3  6.2  4.2  6.   3.7  4.1  5.8  5.6  5.5  4.4  4.6
#   5.9  3.9  3.1  2.9  5.2  3.3  4.7  5.1  3.5  2.5  1.9  3.   2.7  2.2
#   2.   9.5  2.1  3.6  2.8  1.8  3.8  0.   1.6  9.6  2.4  1.7  1.1  0.3
#   1.5  0.7  1.2  2.3  0.5  1.3  0.2  0.6  1.4  0.9  1.   9.7]
# user_score  : кол-во 0 1 , процент 0 0.01 %
# user_score : кол-во NaN 0 , процент NaN 0.0 %
# -------------------------
# rating ['E' -1 'M' 'T' 'E10+' 'K-A' 'AO' 'EC' 'RP']
# rating  : кол-во 0 0 , процент 0 0.0 %
# rating : кол-во NaN 0 , процент NaN 0.0 %

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Вот, что у нас написано в задании: <br><b>
# Опишите причины, которые могли привести к пропускам</b> <br>А мы это не сделали.</font>

# %% [markdown]
# </font><font color='Blue'><b>Пропуски в рэйтинге связаны с тем что оценка рейтинга не распространяется на игры вне Северной америки. Пропуски в оценке пользователей и критиков могут быть связаны с тем что некоторые игры проджались слишком маленьким тиражем и на них не выделялось внимание критиков. Так же игры которые еще не вышли так же не оценены не критиками ни пользователями.</b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Анализ причин пропусков позволяет нам принять правильное решение по их обработке.</font>

# %% [markdown]
# ##  Исследовательский анализ данных

# %% [markdown]
# ### Посмотрим  сколько копий игр было продано всего в каждый год.

# %%
sum_sales_years = data.query('year_of_release> 1').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(grid=True, figsize=(13, 8))

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошая визуализация. 👍</font><br>
# <font color='DarkMagenta'>👉 А вот подписи по оси Y и названия графика не хватает. Это относится и к некоторым другим графикам проекта.</font>

# %%
sum_sales_years_1=data.query('year_of_release> 1').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum')
sum_sales_years_1.sort_values("year_of_release",ascending=False)
# Out:
#                  sum_sales
# year_of_release
# 2016                129.94
# 2015                267.98
# 2014                331.53
# 2013                361.24
# 2012                355.84
# 2011                507.58
# 2010                590.13
# 2009                658.82
# 2008                671.50
# 2007                604.75
# 2006                517.71
# 2005                457.82
# 2004                418.68
# 2003                357.54
# 2002                394.97
# 2001                331.46
# 2000                201.66
# 1999                251.11
# 1998                256.31
# 1997                201.07
# 1996                199.15
# 1995                 88.12
# 1994                 79.23
# 1993                 45.99
# 1992                 76.16
# 1991                 32.23
# 1990                 49.37
# 1989                 73.45
# 1988                 47.21
# 1987                 21.70
# 1986                 37.08
# 1985                 53.95
# 1984                 50.35
# 1983                 16.80
# 1982                 28.88
# 1981                 35.68
# 1980                 11.38

# %% [markdown]
#  Как мы видим в 1996 году начинается резкое увеличение кол-ва проданых копий(больше чем в 2 раза) по сравнению с предыдущим. Стойкая положительная динамика наблюдается до 2008 года, в 2009 году начинается сильно снижение. Связано это скорее всего с ипотечным кризисом в США в 2008 году. Большое кол-во комнапний обонкротились, те кто остался на плаву пересмотрели политику и начали уменьшать кол-во выпускаемых проектов. Из-за этого некоторые игровые жанры "умерли". Так же примерно в это время срок разработок игр и затрат на них начал сильно увеличиваться.

# %% [markdown]
# # Исходя из увиденного для анализа можно использовать не все данные, а только те где год выпуска больше или равно 1994 году. т.к. значения предыдущих лет слишком низкие. А чем больше данных тем более точными будут прогнозы и аналитика

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам

# %% [markdown]
# #### Выберем самые популярные платформы

# %%
sum_sales_platform=data.query('year_of_release> 1996').pivot_table(index='platform', values='sum_sales', aggfunc='sum')
#сделаем сводную таблицу по сумме продаж копий игр на каждой платформе
sum_sales_platform.sort_values("sum_sales",ascending=False)
# Out:
#           sum_sales
# platform
# PS2         1233.56
# X360         961.24
# PS3          931.34
# Wii          891.18
# DS           802.76
# PS           590.89
# PS4          314.14
# GBA          312.88
# PSP          289.53
# 3DS          257.81
# XB           251.57
# PC           224.99
# GC           196.73
# N64          183.91
# XOne         159.32
# GB           100.27
# WiiU          82.19
# PSV           53.81
# DC            15.95
# SAT           10.68
# SNES           1.47
# WS             1.42

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 При анализе принято визуализировать результаты в виде графиков или диаграмм. Таблицы малоинформативны и не наглядны.</font>

# %% [markdown]
# #### Рассмотрим продажи по годам первых 6 платформ самых популярных платформ.

# %% [markdown]
# Сначала рассмотри консоли PS т.к. 3 из них находятся в топ 6 по кол-ву проданных копий и являются приемниками друг друга.

# %%
data.query('platform == "PS"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %%
data.query('platform == "PS2"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %%
data.query('platform == "PS3"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# Для боллее коректного анализа возьмем так же консоль PS4 не входящую в топ 6.

# %%
data.query('platform == "PS4"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# В слуаях с Sony консоли нового поколения выпускаются раз в 6 лет. При этом видно в что в первый год выхода консоли нового поколения, предыдущее не сильно теряет своб актуальность. Т.к на консоль нового поколения выходит не так много игр. Разработчикам нужно время чтобы перейти на новую архитектуру консолей. Поэтому Самые лучше показатели продаж у консолей Sony приходились на 2-7 год существования консоли.

# %% [markdown]
# Вывод: Исходя из этих данных видно что консоли каждого поколения у Sony существуют примерно 10 лет. При этом первый год и последнии 3 большого количества продаж копий игр не будет. Однако в окне сущетсвования консоли 2-7 год будет максимальное кол-во проданных копий.Так же мы видим что консоль последнее поколения PS4 сейчас стремиться к своим пиковым значениям по продажам копий игр, на  16 год нельзя ссылаться на 100%  потому что данные за 16 год не полные.

# %% [markdown]
# Разберем оставшиеся платформы из топа.

# %%
data.query('platform == "X360"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# Вывод: также как и у Sony цикл жизни консоли примерно 10 лет. И так же как и sony пик проданных копий приходиться на окно 2-8 года сущетсвования консоли.

# %%
data.query('platform == "Wii"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# Вывод:Как мы видим консоль так же была актуальна около 10 лет. Правда ее пик активности пришелся на первые 5 лет сущетсвования консоли , при этом пятый год был первым годом снижения кол-ва проданных копий.

# %%
data.query('platform == "DS"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# на данном графике мы видим аномальные значения в 1985 году. Не будем учитывать эти данные.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Мы молодцы, нашли ошибку с платформой DS. Там всего одна игра в 1985 году, но в этом году данной платформы не существовало, явно ошибка.</font>

# %% [markdown]
# Вывод: актуальность консоли  составляет  10 лет.  Первый и последнии 2 года существования платформы показывают достаточно низкие показатели относительно их пиковых значений в интервале 2-8 года сущетсвования консоли.

# %% [markdown]
# # Вывод: На консоль продаются копии игр 10 лет . Самое большое кол-во копий приносят 2-7 год существования консоли. Дальше у всех рассмотренных платформ снижается кол-во.

# %% [markdown]
# #### Рассмотрим данные для платформ за полседние 3 года включая 13 год  и сравним.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно выбран актуальный период. 👍 Сейчас в наше динамичное время в бизнесе уже используются для прогноза периоды в 2-3 года.</font>

# %%
actual_data=data.query('year_of_release > 2012')#сделаем срез актуальных данных

# %% [markdown]
# Рассмотрим продажи относительно платформ.

# %%
actual_data.pivot_table(index='platform', values='sum_sales', aggfunc='sum').sort_values('sum_sales', ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='platform'>

# %% [markdown]
# Как мы видим самые популярные платформы это платформы главных конкурентов. Sony с их PS4 и Xbox c XOne.
# Из графиков выше помним что PS3 Уже заканчивает свой пиковый цикл и идет на спад. т.к вышла более актуальная и свежая модель Ps4.

# %% [markdown]
# Разберем пободробнее продажи топовых платформ  . Платформы PS3 разбирать не будем  т.к. она неактуальная модель закнчивающая свой жизненный цикл и PS4 т.к она уже разобрана выше. Так же не будем разбирать платформу X360 по той же причине.

# %%
actual_data.query('platform == "XOne"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# Как мы видим как в и в случае с PS4 Платформа XOne являеться платформой нового поколения. Пришедшей на смену x360.Исходя из выводов сделаных выше
# она еще приблизительно 3-4 года будет находиться на пике своих возможностей по продажам копий игр. Платформу x360 не будем рассматривать из-за ее неактуальнности.

# %%
actual_data.query('platform == "3DS"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# Посмотрим график продаж данной платформы за все время.Есть предположение что платформа подходит к концу своего жизнено цикла.

# %%
data.query('platform == "3DS"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# В 2017 году у консоли будет 7 год ее сущетсвования, в ближайшие 1-2 года она станет полностью не актуальной.

# %%
data.query('platform == "WiiU"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# Так же рассмотрим PC

# %%
data.query('platform == "PC"').pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# Кол-во проданых копий у PC значительно ниже чем у других топовых платформ однако у пс срок акутальности не заканчивается, и данна платформа актуально всегда.

# %% [markdown]
# # Вывод : На данный момент самые акутальные плафтормы это PS4, XOne и WiiU и Pc. При этом идет общая тендеция для всех платформ на снижения кол-ва проданых копий с каждым годом.

# %% [markdown]
# ### Построим график "ящик с усами". По общим продажам игр по акутальным платформам  платформам за актуальынй период.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Почему мы строим диаграммы размаха с фильтрацией по платформам? В задании топ-платформы не требуются, предполагаются все за актуальный период. Мы таким образом теряем значимую информацию. И диаграммы размаха надо строить в двух видах, в полном, со всеми выбросами и масштабированном с крупными боксплотами. Для вывода только нижней части boxplot-ов необходимо использовать параметр ylim. </font>

# %%
actual_data.boxplot(column=['sum_sales'],by="platform",grid=False,  fontsize=30,figsize= (15, 15))
# Out:
# <AxesSubplot:title={'center':'sum_sales'}, xlabel='platform'>

# %% [markdown]
#  </font><font color='Blue'><b>Исправил</b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 А где диаграмма с крупными боксплотами?</font>

# %%
# Комментарий ревьюера 2
import seaborn as sns
data_temp, y = actual_data.copy(), 'sum_sales'
plt.figure(figsize=(13, 8))
(sns.boxplot(data = data_temp, y = y, x='platform')
    .set(title = 'Продажи по перспективным платформам', xlabel = 'Платформы', ylabel = 'Общие продажи'))
plt.show()
plt.figure(figsize=(13, 8))
(sns.boxplot(data = data_temp, y = y, x='platform')
    .set(title = 'Продажи по перспективным платформам', xlabel = 'Платформы', ylabel = 'Общие продажи', ylim=(0, 2)))
plt.show()

# %% [markdown]
# #### Вывод: Как видно из графика на всех 4 платформах есть болшие выбросы , связанно это скорее всего со сверх популярными играми.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Для интерпретации диаграмм размаха помогает вспомнить, что означают боксплоты:</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Это весь ввод, который мы можем сделать из анализа?</font>

# %% [markdown]
# ### Посмотри как влияют оценки критиков и пользователей на кол-во проданых копий внутри платформ.

# %%
ps4_critic= actual_data.query('platform == "PS4" and critic_score > -1') 
ps4_user= actual_data.query('platform == "PS4" and user_score > -1') 
pc_critic= actual_data.query('platform == "PC" and critic_score > -1 ') 
pc_user=actual_data.query('platform == "PC" and user_score > -1 ')
wiiu_critic= actual_data.query('platform == "WiiU" and critic_score > -1 ') 
wiiu_user= actual_data.query('platform == "WiiU" and user_score > -1 ') 
xone_critic= actual_data.query('platform == "XOne" and critic_score > -1 ') 
xone_user= actual_data.query('platform == "XOne" and user_score > -1 ')

# %% [markdown]
# Посчитаем кореляцию пар проданные копии-оценка критиков и проданные копии- оценка пользователей.

# %%
#ps4_critic.pivot_table(index='critic_score',values='sum_sales').plot(y='sum_sales', kind='line')
#print("Кореляция пары проданные копии-оценка критиков PS4" )
#print(ps4_critic['sum_sales'].corr(ps4_critic['critic_score']))

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Вот, что у нас написано в задании: <br><b>Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.</b> <br>Требуется постоить диаграммы рассеяния, а не линейные диаграммы.</font>

# %%
#ps4_user.pivot_table(index='user_score',values='sum_sales').plot(y='sum_sales', kind='line')
#print("Кореляция пары проданные копии-оценка пользователей PS4" )
#print(ps4_user['sum_sales'].corr(ps4_user['user_score']))

# %% [markdown]
# #### Вывод. Кореляци пар слишком низкая чтобы можно было утвержать что оценки критиков и пользователей влияют на продажи. Однако если оценка от критиков больше 90 кол-во проданых копий будет большими.

# %% [markdown]
#  Посчитаем кореляцию пар проданные копии-оценка критиков и проданные копии- оценка пользователей.

# %% [markdown]
#  Посмотрим графики и посчитаем кореляцию по другим платформам по другим платформам

# %%
#pc_critic.pivot_table(index='critic_score',values='sum_sales').plot(y='sum_sales', kind='line')
#print("Кореляция пары проданные копии-оценка критиков PC" )
#print(pc_critic['sum_sales'].corr(pc_critic['critic_score']))
#pc_user.pivot_table(index='user_score',values='sum_sales').plot(y='sum_sales', kind='line')
#print("Кореляция пары проданные копии-оценка пользователей PC" )
#print(pc_user['sum_sales'].corr(pc_user['user_score']))

# %%
#wiiu_critic.pivot_table(index='critic_score',values='sum_sales').plot(y='sum_sales', kind='line')
#print("Кореляция пары проданные копии-оценка критиков WiiU" )
#print(wiiu_critic['sum_sales'].corr(wiiu_critic['critic_score']))
#wiiu_user.pivot_table(index='user_score',values='sum_sales').plot(y='sum_sales', kind='line')
#print("Кореляция пары проданные копии-оценка пользователей WiiU" )
#print(wiiu_user['sum_sales'].corr(wiiu_user['user_score']))

# %%
#xone_critic.pivot_table(index='critic_score',values='sum_sales').plot(y='sum_sales', kind='line')
#print("Кореляция пары проданные копии-оценка критиков XOne" )
#print(xone_critic['sum_sales'].corr(xone['critic_score']))
#xone.pivot_table(index='user_score',values='sum_sales').plot(y='sum_sales', kind='line')
#print("Кореляция пары проданные копии-оценка пользователей XOne" )
#print(xone['sum_sales'].corr(xone['user_score']))

# %% [markdown]
# Опять случайно удалил ваш коментарий что надо все графики переделать

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='DarkMagenta'>👉 😡</font>

# %%
ps4_critic.plot(x='critic_score', y='sum_sales', kind='scatter', alpha=0.2)
print("Кореляция пары проданные копии-оценка критиков PS4")
print(ps4_critic['sum_sales'].corr(ps4_critic['critic_score']))
ps4_user.plot(x='user_score', y='sum_sales', kind='scatter', alpha=0.2)
print("Кореляция пары проданные копии-оценка пользователей PS4" )
print(ps4_user['sum_sales'].corr(ps4_user['user_score']))
# Out:
# Кореляция пары проданные копии-оценка критиков PS4
# 0.406567902061781
# Кореляция пары проданные копии-оценка пользователей PS4
# -0.031957110204556376

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠  Мы забыли отфильтровать заглушки в оценках критиков и пользователей.  И корреляцию считаем с заглушками. Только одновременно отфильтровывать их не надо. Если мы анализируем отзывы пользователей, то фильтруем заглушки по ним. Если анализируем отзывы критиков, то фильтруем эти заглушки. А вот удаление одновременно и тех и других ведет к необоснованному удалению данных.</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# </font><font color='Blue'><b>Выше исправил срези, снизу графики. Вроде бы все верно.</b></font><br>

# %%
wiiu_critic.plot(x='critic_score', y='sum_sales', kind='scatter', alpha=0.2)
print("Кореляция пары проданные копии-оценка критиков PS4")
print(wiiu_critic['sum_sales'].corr(wiiu_critic['user_score']))
wiiu_user.plot(x='user_score', y='sum_sales', kind='scatter', alpha=0.2)
print("Кореляция пары проданные копии-оценка пользователей PS4" )
print(wiiu_user['sum_sales'].corr(wiiu_user['user_score']))
# Out:
# Кореляция пары проданные копии-оценка критиков PS4
# 0.3586664814609293
# Кореляция пары проданные копии-оценка пользователей PS4
# 0.4193304819266187

# %%
xone_critic.plot(x='critic_score', y='sum_sales', kind='scatter', alpha=0.2)
print("Кореляция пары проданные копии-оценка критиков xone")
print(xone_critic['sum_sales'].corr(xone_critic['user_score']))
xone_user.plot(x='user_score', y='sum_sales', kind='scatter', alpha=0.2)
print("Кореляция пары проданные копии-оценка пользователей xone" )
print(xone_user['sum_sales'].corr(xone_user['user_score']))
# Out:
# Кореляция пары проданные копии-оценка критиков xone
# 0.0010791571372793945
# Кореляция пары проданные копии-оценка пользователей xone
# -0.06892505328279412

# %%
pc_critic.plot(x='critic_score', y='sum_sales', kind='scatter', alpha=0.2)
print("Кореляция пары проданные копии-оценка критиков PS4")
print(pc_critic['sum_sales'].corr(pc_critic['user_score']))
pc_user.plot(x='user_score', y='sum_sales', kind='scatter', alpha=0.2)
print("Кореляция пары проданные копии-оценка пользователей PS4" )
print(pc_user['sum_sales'].corr(pc_user['user_score']))
# Out:
# Кореляция пары проданные копии-оценка критиков PS4
# -0.08956264686921601
# Кореляция пары проданные копии-оценка пользователей PS4
# -0.09384186952476739

# %% [markdown]
#  </font><font color='Blue'><b>Построил</b></font><br>

# %%
# Вывод: Сильной  зависимоти от оценок пользоватейлей и критиков нет, значения корреляции слишком низкие, однако по графикам видно что игры с высокой оценкой от критиков (больше 90) , продаются большим кол-вом копий чем остальные.

# %% [markdown]
# </font><font color='Blue'><b>Вывод: Сильной  зависимоти от оценок пользоватейлей и критиков нет, значения корреляции слишком низкие.</b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='DarkGreen'>👌 Для оценки корреляции лучше пользоваться вот этой шкалой:</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Посмотрим на общее распределие игр по жанрам.

# %%
actual_data.pivot_table(index='genre', values='sum_sales', aggfunc='mean').sort_values('sum_sales', ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='genre'>

# %% [markdown]
# # Из данного графика видим, что самыми популярными жанрами игр будут в  Экшн-игры, Шутеры, Спорт, Рпг. При этом остальные жанры больше чем в 2 раза уступаю самому маленькому жанру из топ 4 РПГ.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Мы здесь попали в ловушку, что максимальные продажи являются самыми прибыльными. Но у нас в данных продажи по жанру для разных платформ, и если одна платформа со своей одной игрой в данном жанре выстрелила, а остальные провалились, то мы все равно будем видеть максимум общих продаж, даже если остальные платформы провалились. Но для прибыльности нам нужен стабильные жанры, который приносит доход не зависимо от платформы, значит на этот жанр есть устойчивый спрос.</font><br>
# <font color='Red'>🛠 По этому нам лучше добавить сравнение медианных продаж, проиллюстрировав их диаграммами размаха и изменить промежуточные выводы.</font>

# %% [markdown]
#  </font><font color='Blue'><b> Исправил на среднее. Вывод: самые популярные жанры Шутеры, Спорт и Платформеры </b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 В проекте под "прибыльностью" понимается наличие устойчивого спроса пользователей на данный жанр. Можно сделать уникальный сюжет, быстрый движок, красивую графику и вложить немеряно денег в рекламу и продажи игры подпрыгнут. Но нам лучше выбирать игру из жанра, на которой есть постоянный спрос независимо от маркетинговых усилий производителей игр.<br>
# Это хороший пример, когда на одних и тех же данных разные диаграммы дают разный анализ. Визуализация это не только красивое представление табличных данных, а еще и инструмент анализа.</font>

# %% [markdown]
# ##  Составление  портрета  пользователя каждого региона.

# %% [markdown]
# ### Посмотрим доли продаж на рынках Европы, Японии и Америки топ 5 актуальный платформ  за актуальный период, определенных выше

# %% [markdown]
# Посмотрим сумарные продажи по 3 регионам за актуальный период.

# %%
top_platform_actual=actual_data.query('platform == "PS4" or platform == "PS3" or platform == "3DS" or platform == "XOne" or platform == "X360" and year_of_release > 2012 ')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 4</b></font><br>
# <font color='DarkMagenta'>👉 Не правильно фильтровать по указанному списку платформ, топ надо получать сортировкой по продажам в конкретном регионе и брать срезом первые пять. Код должен быть универсальным, если нам завтра принесут датасет с данными и за следующий год, а попросят сделать прогноз на 2018 год, то мы просто загружаем датасет, корректируем актуальный период и перезапускаем тетрадку. А тут придется руками править. 😢</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 В задании требуется построить топ-5, а не топ-4. И топ выбирается по максимальной суммы продаж за актуальный период. И топ в каждом регионе разный.</font>

# %%
#</font><font color='Blue'><b>добавил в top_platform_actual  PSV </b></font><br>

# %%
top_platform_actual_na=top_platform_actual[["na_sales","platform"]]#Возьмем данные нужные нам для построение круговой диаграмы
top_platform_actual_na.groupby(['platform']).sum().plot(kind='pie', y='na_sales',autopct='%1.0f%%',figsize= (7, 7))# построим круговую диаграму
# Out:
# <AxesSubplot:ylabel='na_sales'>

# %%
top_platform_actual_eu=top_platform_actual[["eu_sales","platform"]]
top_platform_actual_eu.groupby(['platform']).sum().plot(kind='pie', y='eu_sales',autopct='%1.0f%%',figsize= (7, 7))# построим круговую диаграму
# Out:
# <AxesSubplot:ylabel='eu_sales'>

# %%
top_platform_actual_jp=top_platform_actual[["jp_sales","platform"]]
top_platform_actual_jp.groupby(['platform']).sum().plot(kind='pie', y='jp_sales',autopct='%1.0f%%',figsize= (7, 7))# построим круговую диаграму
# Out:
# <AxesSubplot:ylabel='jp_sales'>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='Red'>🛠 Ошибка не исправлена, в Японии другой топ!</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# </font><font color='Blue'><b>исправил</b></font><br>

# %%
# Исходя  из данных предоставленых выше мы видим что, в Европе и Америке предпочтение отдают 2 конкурирующим консолям PS4 и XOne. В америки на их долю приходиться 83% рынка, а в европе 81%. В Японии покупатели предпочитают консоли отечетсвенного производства PS4 и WiiU  на них приходиться 99% рынка. При этом на всех 3 рынках доминирует PS4

# %%
# </font><font color='Blue'><b> Исходя из данных мы видим что в Японии покупатели предпочитают консоли отечетсвенного производства PS4 и WiiU  на них приходиться 99% рынка. В Америке идет сильная конруренца между 3 платформами PC, Ps4 и Xbox.</b></font><br>

# %% [markdown]
# # </font><font color='Blue'><b> Исходя из данных мы видим что в Японии покупатели предпочитают консоли отечетсвенного производства 3DS,PS4 и Ps3.В Америке предпочитают PS4,Xone и X360.В европе PS4, Ps3 и Xone

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='DarkMagenta'>👉 Вот портрет для актуального периода с 2014 года:</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Посмотрим препочтения покупателей по жанрам в 3 регионах

# %%
top_genre_actual_na=actual_data[["na_sales","genre",]]#Возьмем данные нужные нам для построение круговой диаграмы
top_genre_actual_na.groupby(['genre']).sum().plot(kind='pie', y='na_sales',autopct='%1.0f%%',figsize= (12, 12))# построим круговую диаграму
# Out:
# <AxesSubplot:ylabel='na_sales'>

# %%
top_genre_actual_eu=actual_data[["eu_sales","genre"]]#Возьмем данные нужные нам для построение круговой диаграмы
top_genre_actual_eu.groupby(['genre']).sum().plot(kind='pie', y='eu_sales',autopct='%1.0f%%',figsize= (12, 12))# построим круговую диаграму
# Out:
# <AxesSubplot:ylabel='eu_sales'>

# %%
top_genre_actual_jp=actual_data[["jp_sales","genre"]]#Возьмем данные нужные нам для построение круговой диаграмы
top_genre_actual_jp.groupby(['genre']).sum().plot(kind='pie', y='jp_sales',autopct='%1.0f%%',figsize= (12, 12))# построим круговую диаграму
# Out:
# <AxesSubplot:ylabel='jp_sales'>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Хорошо сделан анализ и визуализирован круговыми диаграммами. А вот данные не вошедшие в ТОП, как правило, суммируют и выводят отдельной группой "Другие". Тогда на такой диаграмме хорошо видны все региональные рынки игр с разбиением на платформы/жанры. Какая платформа/жанр занимает какую долю рынка. И наша визуализация несет определенную бизнес-логику, связанную именно с долями рынка занимаемыми платформами/жанрами. А этого не дают другие виды диаграмм.  Примерно вот так:</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# # Как мы видим из данных. В Америке и Европе самыми популярными жанрами являются ЭКШН игры и Шутеры , топ 3 закрывают игры жанра спорт. Однако в Японии опять другие предпочтения. На первом месте по популярности у них Экш игры, на втором РПГ и топ 3 закрывают игры жанра Шутеры.

# %% [markdown]
# </font><font color='Blue'><b> Подкоректировал вывод после добавления PSV </b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='Red'>🛠 Анализ должне проводиться по всему датасету актуального периода, без фильтрации по платформам.</font>

# %% [markdown]
# </font><font color='Blue'><b>Исправил </b></font><br>

# %% [markdown]
# ### Оценим влияет ли рейтинг на продажи в отдельном регионе ESRB

# %%
actual_data.pivot_table(index='rating', values="na_sales", aggfunc='sum').sort_values("na_sales", ascending=False).plot(kind='pie', y="na_sales", autopct='%1.0f%%', figsize=(7, 7))
actual_data.pivot_table(index='rating', values="eu_sales", aggfunc='sum').sort_values("eu_sales", ascending=False).plot(kind='pie', y="eu_sales", autopct='%1.0f%%', figsize=(7, 7))
actual_data.pivot_table(index='rating', values="jp_sales", aggfunc='sum').sort_values("jp_sales", ascending=False).plot(kind='pie', y="jp_sales", autopct='%1.0f%%', figsize=(7, 7))
# Out:
# <AxesSubplot:ylabel='jp_sales'>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='Red'>🛠 И здесь надо использовать весь датасет, а не топ платформ.</font>

# %% [markdown]
# </font><font color='Blue'><b>Исправил</b></font><br>

# %% [markdown]
# Как мы видим игр графиков на Американском и европейском рынке пользователи отдают предпочтение играм с рейтингом "M". Дальше по полуряности идут "M" .В Японии пердпочитают игры с рейтингом "T" ,  отсутсвует рейтинг у  большого числа игр это связано с тем что в Японии есть своя компания занимающаясе присвоением рейтинга Computer Entertainment Rating Organization.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Вот такая проблема была с рейтингом. <br>
# А дело в том, что если посмотреть в инете, что из себя представляет рейтинг ESRB, то окажется, что он предназначен для маркировки игр для США и Канады. И логично, что для других регионов он не заполняется. А в Японии есть свой рейтинг, свой рейтинг есть в ЕС и отдельно в Германии, Австралии и т.д., но по ним у нас нет данных. То есть, в данном случае пропуск имеет признак, что игра выпущена не в Северо-Американском регионе. Необходимо шире смотреть на исходный датасет, так как за цифрами находятся реальные бизнес-процессы. Мы должны это учитывать при предобработке данных. 👍</font>

# %% [markdown]
# #### Общий вывпод по регионам: Американский и Европейский рынок очень похожи по предпочтениям На обоих рынках самыми популярными платформами являются PC, PS4 и XOne , покупатели этих 2 регионов предпочитают игры в жанре "Экш", "Шутер" и игры жанра "Спорт" с рейтингом "M" («Mature») — «Для взрослых»: Материалы игры не подходят для лиц младше 17 лет. Проекты с данным рейтингом могут содержать достаточно жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории. . Японский регион отличается особыми вкусами, платформы они предпочитают отчественные PSV, PS4 и WiiU. Жанры предпочитают игры в жанре Экш, Рпг и шутеры. Влияние рейтинга на это регион сложно оценить достоверно. Изходя из имеющихся данных предпочитают игры с рейтингом "Т", однако это всего 18%. 41% данных отсутсвует т.к. в японии присвоением рейтинга занимается "Computer Entertainment Rating Organization". Для более точного анализа нужны дополнительные данные.

# %% [markdown]
# ### Сформулируем гиппотезы и проверим их.

# %% [markdown]
# #### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.

# %% [markdown]
# Сформулируем основную и альтернативную гипотизы

# %% [markdown]
# H0: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.

# %% [markdown]
# H1: Средние пользовательские рейтинги платформ Xbox One и PC различаются.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, правильно сформулированы гипотезы.</font>

# %% [markdown]
# #### Проверим их

# %%
from scipy import stats as st

# %%
#xboxr=xone_us.query("user_score > -1")# готови данные для проверки гипотезы так как user_score=0 означает что оценка отсутсвует

# %%
#pcr=pc.query("user_score > -1")# готови данные для проверки гипотезы так как user_score=0 означает что оценка отсутсвует

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что отфильтровали заглушки. Но лучше было `!=0`.</font>

# %%
# results = вызов метода для проверки гипотезы
alpha = .05

results = st.ttest_ind(
    xone_user['user_score'],
    pc_user['user_score'],  
)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.14012658403611647
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно, что для тестирования гипотез использован двусторонний t-тест.</font>

# %%
print("Cредняя оценка пользователей Xbox " , xone_user['user_score'].mean())
print("Cредняя оценка пользователей PC" , pc_user['user_score'].mean())
# Out:
# Cредняя оценка пользователей Xbox  6.521428571428572
# Cредняя оценка пользователей PC 6.2696774193548395

# %% [markdown]
# #### Вывод: Не смотря на то что средние оценки пользователей по платформам различаются , вероятность получить такое значение очень низкое (14%). Отвергнуть нулевыую гипотезу мы не можем. Следовательно нулевая гипотеза верна.

# %% [markdown]
# #### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# Сформулируем основную и альтернативную гипотизы

# %% [markdown]
# H0: Средние пользовательские рейтинги жанров Action и Sports одинаковые.

# %% [markdown]
# H1: Средние пользовательские рейтинги жанров Action и Sports различаются.

# %% [markdown]
# #### Проверим их

# %%
action=actual_data.query("genre == 'Action' and user_score > -1")# готови данные для проверки гипотезы так как user_score=0 означает что оценка отсутсвует

# %%
sports=actual_data.query("genre == 'Sports' and user_score > -1")# готови данные для проверки гипотезы так как user_score=0 означает что оценка отсутсвует

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
#     <font color='Red'>🛠 Используется сокращенный датасет актуального периода, а не полный `actual_data`.</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# </font><font color='Blue'><b>исправил</b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Что у нас написано в задании: <br><b>Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. <br>Не учитывайте в работе данные за предыдущие годы.</b> <br>После определения актуального периода мы дальнейший анализ делаем только за этот период. А тут у нас датасет отфильтрованный по платформам.</font>

# %%
# results = вызов метода для проверки гипотезы
alpha = .05

results = st.ttest_ind(
    action['user_score'],
    sports['user_score'],  
)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.0517832389140023e-27
# Отвергаем нулевую гипотезу

# %%
print("Cредняя оценка жанра Action " , action['user_score'].mean())
print("Cредняя оценка пользователей Sprot" , sports['user_score'].mean())
# Out:
# Cредняя оценка жанра Action  6.837532133676092
# Cредняя оценка пользователей Sprot 5.238124999999999

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно, что показаны дополнительно средние пользовательские рейтинги и по платформам, и по жанрам, как иллюстрации не противоречивости наших гипотез.</font>

# %% [markdown]
# #### Вывод: Средние пользовательские оценки  различаются. Вероятность случайно получить одинаковые результаты очень мало . Следовательно, cредние пользовательские рейтинги жанров Action и Sports  различаются и наша гипотеза подтвердилась.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Необходимо сделать выводы по данному разделу согласно заданию:<br>
# <b>Поясните:<br>
# Как вы сформулировали нулевую и альтернативную гипотезы;<br>
# Какой критерий применили для проверки гипотез и почему.</b>
# </font>

# %% [markdown]
# </font><font color='Blue'><b> как я формулировал указано в H0 и H1 не понимаю что еще надо указывать. </b></font><br>

# %% [markdown]
# </font><font color='Blue'><b> Критерием проверки гипотезы являеться значение p-value,p-value это вероятность ошибки нулевой гипотезы.Он показывает веротяность получения такоже значение статистики (среднего арифметического, медианы и др.) при другом наборе данных   </b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 Гипотезы сформулированы для t-критерия Стьюдента - вопрос почему? Для разных критериев формулируются свои гипотезы.</font>

# %% [markdown]
# При использовании t-критерия Стьюдента важно, чтобы объекты исследования или анализируемые выборки были распределены равномерно и имели хотя бы минимальное взаимодействие: относились к одной и той же среде. t-критерий Стьюдента лучше всего использовать в случаях, когда известны средние значения выборки. Например, эксперт намерен проанализировать средний возраст жителей Сибири и средний возраст россиян по стране.

# %% [markdown]
# </font><font color='Blue'><b> Сверху вырезка со стороннего сайта, так как я плохо понял этот материал в прошлой теме. Я посчитал что в данном случае этот метод подойдет. т.к. выборки из одной сферы. Так же мы можем посчитать среднее значение выборки.И по итогам t-теста и посчитаным средним сделать правильные выводы. </b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 3</b></font><br>
# <font color='DarkMagenta'>👉 Рекомендую прочитать статью: https://allatambov.github.io/psms/pdf/hypo-test.pdf</font>

# %% [markdown]
# # Общий вывод:

# %% [markdown]
# В 2009 году начался спад продаж во всей индустрии, и динамика продолжается до сих пор.

# %% [markdown]
# На данный момент платформы сменяют друг друга в среднем раз в 10 лет. Однако это зависит от конкуренции.

# %% [markdown]
# Оценки критиков и игроков не влияют напрямую на кол-во продаваемых копий. Однако игры с рейтингом критиков больше 90 продаются лучше всего.

# %% [markdown]
# Саммые популярные платформы за все время :  PS2, X360, PS3, Wii, DS.

# %% [markdown]
# Самые популярные актуальные платформы это: PS4, XOne, WiiU, PC.

# %% [markdown]
# Самые популярные Жанры в мире  это : Action, Shooters и Sport.

# %% [markdown]
# </font><font color='Blue'><b> Самые популярные Жанры в мире это : Шутеры, Спорт и Платформеры </b></font><br>

# %% [markdown]
# Покупатели в Европе и Америке предпочитают играть на консолях PS3 ,PS4, XOne. В игры в жанре Action, Shooters и Sport ,  с рейтингом "М" от "Entertainment Software Rating Board" . При подборе игры и консолей для этих регионов в первую очень стоит обращать внимание именно на эти параметры.

# %% [markdown]
# Покупатели в Японии предпочитают предпочитают играть на консолях 3DS,PS4 и Ps3. В игры в жанре Action, RPG  , с рейтингом "T" от Entertainment Software Rating Board. Так же ,дополнительно, имеемт смысл проанализировать японский рынок отдельно, в случае жалние допольнительного расширения влияния на этом рынке. т.к. в связи с культурными особенностями их предпочтения отличают от Европы и Америки и они имеют свою организаци занимающейся оценкой рейтинга "Computer Entertainment Rating Organization". . При подборе игры и консолей для этих регионов в первую очень стоит обращать внимание именно на эти параметры.

# %% [markdown]
#  Рекомендуется добавить дополнительную информация по онлайн играм. По играм в жанрах которые здесь не указаны MMORPG, MOBA.Эти жанры относительно довольно популярны во всем мире.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Выводы сделаны полные в соответствии с целью исследования. Возможно, придется переделать после иправления ошибок. </font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера</b></font><br><br>
# <font color='DarkGreen'>👌 Станислав, проект отлично структурирован и проработан.<br>Так держать и дальше!<br></font>
# <font color='Red'>🛠 Что нам нужно, что бы сделать проект лучше:</font><br>
# <font color='Red'>🛠 Сделать правильную замену оценок пользователей tbd. Сделать описание причин, которые могли привести к пропускам в датасете. Построить диаграммы размаха по глобальным продажам игр в разбивке по всем платформам актуального периода. Построить диаграммы рассеяния при анализе отзывов. В анализе игр по жанрам надо проанализировать медианные значения продаж, построив диаграммы размаха. Анализ проводить только за полный актуальный период. Необходимо сделать пояснения по разделу гипотез согласно заданию.</font><br>
# <font color='DarkMagenta'>👉 При исправлении ошибок и недочетов мы приобретем дополнительный опыт и навыки!</font><br>
# <font color='DarkGreen'>👌 Жду окончательный вариант! Успехов.</font>

# %% [markdown]
# Внес все изменения , вроде бы ничего не упустил. Измененые выводы пометил синим.
# </font><font color='Blue'><b>Внес все изменения , вроде бы ничего не упустил. Измененые выводы пометил синим. </b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 2</b></font><br><br>
# <font color='DarkGreen'>👌 Станислав, увы, остались еще ошибки.<br></font>
# <font color='Red'>🛠 Что нужно доделать:</font><br>
# <font color='Red'>🛠 Раздельно отфильтровать заглушки при анализе отзывов. Переделать составление портрета пользователя по платформам в разрезе регионов. Анализ проводить только за полный актуальный период. Необходимо сделать пояснения по разделу гипотез согласно заданию.</font><br>
# <font color='DarkGreen'>👌 Жду исправленный вариант! Успехов.</font>

# %% [markdown]
# </font><font color='Blue'><b>Заглушки переделал на -1  и отфильтровал. Портрет пользователей переделал исходя их добавления еще 1 платформы PSV. в гипотезах указал не обрезанные данныею. Пояснения по разделу гипотез постарался внести. Выводы переделал. </b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 3</b></font><br><br>
# <font color='DarkGreen'>👌 Станислав, не все ошибки исправлены.<br></font>
# <font color='Red'>🛠 Что нужно сделать:</font><br>
# <font color='Red'>🛠 Переделать составление портрета пользователя по регионам, используя не фильтрованный датасет актуального периода.</font><br>
# <font color='DarkGreen'>👌 Жду исправленный вариант! Успехов.</font>

# %% [markdown]
# </font><font color='Blue'><b>В топ 5 сделал топ 5 из консолей за акутальный период в рейтингах , в рейтингах использовал актуальную дату без фильтра по консолям.  </b></font><br>

# %% [markdown]
# </font><font color='Blue'><b>Спасибо за ссылку ознакомлюсь.</b></font><br>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 4</b></font><br><br>
# <font color='DarkGreen'>👌 Станислав! Не смотря на яростное сопротивление проекта, мы его победили! Нам удалось справиться со всеми подводными камнями в проекте.  Мы молодцы! 😄<br>
# Мы узнали, что не все пропуски просто ошибки сбора данных, а несут свои признаки. Для этого нам понадобилось за данными датасета увидеть смысл этих данных и бизнес-процессы, которые за ними скрываются. Мы узнали, что медианы могут дать дополнительную информацию при анализе. Это наши новые знания и навыки, которые нам пригодятся в будущем!<br></font>
# <font color='DarkGreen'>👌 Теперь, вперед за новыми знаниями и навыками! Удачи! 😉</font>
# ![image.png](attachment:image.png)
